# %%
# Week 1–2: Data Cleaning & Exploratory Data Analysis (EDA)

## AnalystLab Africa

Name:Akorede Goodness Hannah

## Objective

The objective of this project is to clean, validate, standardize and analyze two datasets (Online Retail and Netflix Movies & TV Shows) using SQL Server and Microsoft Excel.

The project includes:

- Dataset Understanding
- Data Cleaning
- Exploratory Data Analysis (EDA)
- Data Visualization
- Insights

# %% [markdown]
# # Dataset Understanding
#
# Two datasets were used:
#
# 1. Online Retail Dataset
# 2. Netflix Movies & TV Shows Dataset
#
# Both datasets were loaded into SQL Server for analysis and cleaning.

# %% [markdown]
# ## Online Retail Dataset
#
# ### Dataset Description
#
# The Online Retail dataset contains transactional sales data for an online gift store.
#
# ### Dataset Summary
#
# - Total records: 541,909
# - Total columns: 8
# - Numerical columns:
#   - Quantity
#   - UnitPrice
#   - CustomerID
# - Categorical columns:
#   - InvoiceNo
#   - StockCode
#   - Description
#   - Country
# - Date column:
#   - InvoiceDate

# %% [markdown]
# ## Netflix Dataset
#
# ### Dataset Description
#
# The Netflix dataset contains information about movies and TV shows available on Netflix.
#
# ### Dataset Summary
#
# Columns include:
#
# - show_id
# - type
# - title
# - director
# - cast
# - country
# - date_added
# - release_year
# - rating
# - duration
# - listed_in
# - description

# %% [markdown]
# # Data Cleaning Process

# %% [markdown]
# ## Online Retail Cleaning
#
# The following cleaning tasks were performed:
#
# - Checked missing values
# - Checked duplicate records
# - Standardized text formatting
# - Verified data types
# - Identified zero unit prices
# - Identified negative quantities
# - Checked invoice dates
# - Corrected country inconsistencies

# %% [markdown]
# ## Netflix Cleaning
#
# The following cleaning tasks were performed:
#
# - Checked missing values
# - Checked duplicates
# - Removed leading commas in country names
# - Standardized text formatting
# - Verified date format
# - Identified incorrect ratings
# - Detected duration values stored in the rating column

# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# ## Online Retail Analysis
#
# The following analyses were carried out:
#
#
# - Highest revenue-generating countries
#
# ![image.png](data:image/png;base64,...)
#
# - Top spending customers
# ![image.png](data:image/png;base64,...)
# - Customer purchasing behaviour
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Netflix Analysis
#
# The following analyses were carried out:
#
# - Movies vs TV Shows
#
# ![image.png](data:image/png;base64,...)
#
# - Top producing countries
# ![image.png](data:image/png;base64,...)
#
# - Most common genres
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Data Visualizations
#
# The following charts were created in Microsoft Excel:
#
# - Bar Charts
# - Histogram

# %% [markdown]
# # Key Insights
#
# ## Online Retail
#
# - United Kingdom generated the highest sales.
# - Several transactions contained negative quantities, indicating returns.
# - Some records had zero unit prices.
# - Customer purchasing behaviour varied significantly.
# - Revenue was concentrated among a small number of customers.
#
# ## Netflix
#
# - Movies are more common than TV Shows.
# - TV-MA was the most frequent rating.
# - The United States produced the most content.
# - Most content was added after 2016.
# - Some duration values were incorrectly stored in the rating column and were identified during cleaning.
